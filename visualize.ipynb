# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle
import tensorflow as tf

# %matplotlib inline

# %%
ep_length = 400
sim_steps = 50000

# %%
save_data = pickle.load(open("data/data.p", "rb"))
input_x = save_data["x"] # (49999, 7)
input_y = save_data["y"] # (49999, 2)
x = input_y[:400, 0]
z = input_y[:400, 1]

# %%
def create_colors(length, segments):
    c_list = []
    for i in range(segments):
        color = np.zeros([length//segments, 4])
        color[:, 3] = 0.5
        color[:, 0:3] = np.random.uniform(0, 1, size=[1, 3])
        c_list.append(color)
    c_list = np.reshape(c_list, [length, 4])
    return c_list

# %%
plt.figure(figsize=(10, 10))
plt.scatter(x, z, s=1, c=create_colors(sim_steps, sim_steps//ep_length))
plt.ylim(-4.5, 4.5)
plt.xlim(-4.5, 4.5)
# Out:
# (-4.5, 4.5)

# %% [markdown]
# 真ん中あたりの(0.5, -1)あたりがスタート位置で、右上が終了位置

# %% [markdown]
# ## input_xのelement0
# rotationで、-1~1に正規化したもの

# %%
plt.plot(input_x[0:400,0])

# %% [markdown]
# ## input_xのelement1
# velocity x

# %%
plt.plot(input_x[0:400,1])

# %% [markdown]
# ## input_xのelement2
# velocity z

# %%
plt.plot(input_x[0:400,2])

# %% [markdown]
# ## input_xのelement3
# angular velocity

# %%
plt.plot(input_x[0:400,3])

# %% [markdown]
# ## input_xのelement4
# velocity magnitude

# %%
plt.plot(input_x[0:400,4])

# %% [markdown]
# ## input_xのelement5
# heading

# %%
plt.plot(input_x[0:400,5])

# %% [markdown]
# ## input_xのelement6
# velocity?

# %%
plt.plot(input_x[0:400,6])

# %% [markdown]
# ## input_yのX座標

# %%
plt.plot(input_y[0:400,0])

# %% [markdown]
# ## input_yのY座標

# %%
plt.plot(input_y[0:400,1])
